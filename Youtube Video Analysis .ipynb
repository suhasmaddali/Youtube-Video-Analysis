# %% [markdown]
# ## Youtube Video Analysis
#
# Understanding how the videos are being used in youtube can be considered to be one of the important tasks in data science. In this project, we would be understanding the data with the help of different data visualization techniques which would in turn help us in the long term.
#
# We would be working with different data visualization techniques to understand the data and get insights from it. We would be analysing the data with the help of californian data. There are different machine learning techniques and the more we are learning the things in life, the better we are going to get in the long term. We see that machine learning techniques.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import json

# %% [markdown]
# We would be first reading the data. The data contains both the csv file and also the json file respectively. We would be working with these two datasets and understand how the things are being used in different machine learning settings respectively.

# %%
df = pd.read_csv('Youtube Video Analysis/CAvideos.csv')
open_file = open('Youtube Video Analysis/CA_category_id.json')
df_category_json = json.load(open_file)

# %% [markdown]
# We would read the json file which contains the dictionary of the files that we would be considering and working in the long term. These files contain the files that we would be workign in the long term. We are sure that different machine learning models are being used in the long term.

# %%
df_category_json
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#    'id': '1',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Film & Animation',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#    'id': '2',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Autos & Vehicles',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#    'id': '10',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Music',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#    'id': '15',
# ...

# %% [markdown]
# We would be working with the dictionary and understand how the machine leraning models would be working in the test set respectively.

# %%
type(df_category_json)
# Out:
# dict

# %% [markdown]
# We would take a look at the items that contains the list. We are sure that different machine learning models would be used for different machine learning tools and the more we are learnign the different machine learning models, the better we are going to get in the long term.

# %%
type(df_category_json['items'])
# Out:
# list

# %%
len(df_category_json['items'])
# Out:
# 31

# %%
len(df_category_json)
# Out:
# 3

# %%
df_category_json
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#    'id': '1',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Film & Animation',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#    'id': '2',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Autos & Vehicles',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#    'id': '10',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Music',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#    'id': '15',
# ...

# %%
df['category_id'].nunique()
# Out:
# 17

# %%
sns.countplot(x = 'category_id', data = df)
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1296
# dtype: int64

# %%
df.isnull().sum()['description']
# Out:
# 1296

# %%
len(df)
# Out:
# 40881

# %%
percentage_of_missing_values = df.isnull().sum()['description']/len(df) * 100

# %%
print("The percentage of missing values in the data are {}%".format(np.round(percentage_of_missing_values, 2)))
# Out:
# The percentage of missing values in the data are 3.17%

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# dtype: int64

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df_category_json
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#    'id': '1',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Film & Animation',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#    'id': '2',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Autos & Vehicles',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#    'id': '10',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Music',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#    'id': '15',
# ...

# %%
len(df_category_json['items'])
# Out:
# 31

# %%
titles_dict = dict()

# %%
titles_dict
# Out:
# {}

# %%
df_category_json['items'][0]['id']
# Out:
# '1'

# %%
for i in range(len(df_category_json['items'])):
    print(df_category_json['items'][i]['id'])
    print(df_category_json['items'][i]['snippet']['title'])
    id_number = int(df_category_json['items'][i]['id'])
    category = df_category_json['items'][i]['snippet']['title']
    titles_dict[id_number] = category
# Out:
# 1
# Film & Animation
# 2
# Autos & Vehicles
# 10
# Music
# 15
# Pets & Animals
# 17
# Sports
# 18
# Short Movies
# 19
# Travel & Events
# 20
# Gaming
# 21
# Videoblogging
# 22
# People & Blogs
# 23
# Comedy
# 24
# Entertainment
# 25
# News & Politics
# 26
# Howto & Style
# 27
# Education
# 28
# Science & Technology
# 30
# Movies
# 31
# Anime/Animation
# 32
# Action/Adventure
# 33
# Classics
# 34
# Comedy
# 35
# Documentary
# 36
# Drama
# 37
# Family
# 38
# Foreign
# 39
# Horror
# 40
# Sci-Fi/Fantasy
# 41
# Thriller
# 42
# Shorts
# 43
# Shows
# 44
# Trailers

# %%
print(titles_dict)
# Out:
# {1: 'Film & Animation', 2: 'Autos & Vehicles', 10: 'Music', 15: 'Pets & Animals', 17: 'Sports', 18: 'Short Movies', 19: 'Travel & Events', 20: 'Gaming', 21: 'Videoblogging', 22: 'People & Blogs', 23: 'Comedy', 24: 'Entertainment', 25: 'News & Politics', 26: 'Howto & Style', 27: 'Education', 28: 'Science & Technology', 30: 'Movies', 31: 'Anime/Animation', 32: 'Action/Adventure', 33: 'Classics', 34: 'Comedy', 35: 'Documentary', 36: 'Drama', 37: 'Family', 38: 'Foreign', 39: 'Horror', 40: 'Sci-Fi/Fantasy', 41: 'Thriller', 42: 'Shorts', 43: 'Shows', 44: 'Trailers'}

# %%
df['category'] = df['category_id'].map(titles_dict)

# %%
df.drop('category_id', axis = 1, inplace = True)

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#                publish_time  \
# 0  2017-11-10T17:00:03.000Z
# 1  2017-11-13T17:00:00.000Z
# 2  2017-11-12T19:05:24.000Z
# 3  2017-11-12T18:01:41.000Z
# 4  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# ...

# %%
df.drop('video_id', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df.drop('thumbnail_link', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df['ratings_disabled'].unique()
# Out:
# array([False,  True])

# %%
df['video_error_or_removed'].unique()
# Out:
# array([False,  True])

# %%
def true_false_converter(value):
    if value == True:
        return 1
    else:
        return 0

# %%
df['comments_disabled'] = df['comments_disabled'].apply(true_false_converter)
df['ratings_disabled'] = df['ratings_disabled'].apply(true_false_converter)
df['video_error_or_removed'] = df['video_error_or_removed'].apply(true_false_converter)

# %%
df.tail()
# Out:
#       trending_date                                              title  \
# 40876      18.14.06                       HOW2: How to Solve a Mystery
# 40877      18.14.06                   Eli Lik Lik Episode 13 Partie 01
# 40878      18.14.06  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...
# 40879      18.14.06                   Trump Advisor Grovels To Trudeau
# 40880      18.14.06                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#           channel_title              publish_time  \
# 40876   Annoying Orange  2018-06-13T18:00:07.000Z
# 40877  Elhiwar Ettounsi  2018-06-13T19:01:18.000Z
# 40878    Kingdom Hearts  2018-06-11T17:30:53.000Z
# 40879   The Young Turks  2018-06-13T04:00:05.000Z
# 40880          我愛小明星大跟班  2018-06-13T16:00:03.000Z
#
#                                                     tags   views  likes  \
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...   80685   1701
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...  103339    460
# ...

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df['tags'][0]
# Out:
# 'Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/Interscope"|"Rap"'

# %%
df['tags'][1]
# Out:
# 'plush|"bad unboxing"|"unboxing"|"fan mail"|"idubbbztv"|"idubbbztv2"|"things"|"best"|"packages"|"plushies"|"chontent chop"'

# %%
plt.figure(figsize = (20, 10))
plt.xticks(rotation = 45, fontsize = 15)
sns.countplot(df['category'])
plt.show()

# %%
type(df['comments_disabled'][0])
# Out:
# numpy.int64

# %%
df['comments_disabled'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df.shape
# Out:
# (39585, 14)

# %%
df['channel_title'].nunique()
# Out:
# 4773

# %%
sns.countplot(x = 'comments_disabled', data = df)
# Out:
# <AxesSubplot:xlabel='comments_disabled', ylabel='count'>

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
sns.countplot(df['ratings_disabled'])
# Out:
# <AxesSubplot:xlabel='ratings_disabled', ylabel='count'>

# %%
sns.countplot(df['video_error_or_removed'])
# Out:
# <AxesSubplot:xlabel='video_error_or_removed', ylabel='count'>

# %%
print("The total number of videos which have been removed or there is error are {}".format(len(df[df['video_error_or_removed'] == 1])))
# Out:
# The total number of videos which have been removed or there is error are 27

# %%
df.groupby('category').mean()[['views', 'likes', 'dislikes', 'comment_count']]
# Out:
#                              views          likes     dislikes  comment_count
# category
# Autos & Vehicles      5.676173e+05   13555.859195   566.508621    2913.715517
# Comedy                9.891344e+05   52293.700671  1434.022282    5210.148725
# Education             5.370408e+05   21270.646640   803.415479    3014.707739
# Entertainment         1.027834e+06   29272.942914  1947.986412    4178.594246
# Film & Animation      1.459745e+06   38827.168916  1551.424288    5034.012494
# Gaming                9.222066e+05   38750.436090  1830.503008    7250.983459
# Howto & Style         7.845609e+05   25600.145145   864.553053    4173.187187
# Movies                2.853415e+06   42150.833333  2046.666667    2329.833333
# Music                 3.556905e+06  152354.803518  5971.520704   14152.600271
# News & Politics       4.045271e+05    8325.420889   813.498966    2321.836091
# People & Blogs        8.273183e+05   27217.688137  2495.093398    4353.692700
# ...

# %%
df.groupby('category').mean()['views'].sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df.groupby('category').mean()['likes'].sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df.groupby('category').mean()['comment_count'].sort_values().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
plt.figure(figsize = (20, 10))
plt.xticks(rotation = 45)
sns.barplot(x = df['channel_title'].value_counts()[: 20].index, y = df['channel_title'].value_counts()[: 20])
# Out:
# <AxesSubplot:ylabel='channel_title'>

# %%
df['channel_title']
# Out:
# 0              EminemVEVO
# 1               iDubbbzTV
# 2            Rudy Mancuso
# 3                nigahiga
# 4              Ed Sheeran
#                ...
# 40876     Annoying Orange
# 40877    Elhiwar Ettounsi
# 40878      Kingdom Hearts
# 40879     The Young Turks
# 40880            我愛小明星大跟班
# Name: channel_title, Length: 39585, dtype: object

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df['trending_date'][0][:2]
# Out:
# '17'

# %%
df['trending_year'] = df['trending_date'].apply(lambda x: '20' + x[:2])

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df.tail()
# Out:
#       trending_date                                              title  \
# 40876      18.14.06                       HOW2: How to Solve a Mystery
# 40877      18.14.06                   Eli Lik Lik Episode 13 Partie 01
# 40878      18.14.06  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...
# 40879      18.14.06                   Trump Advisor Grovels To Trudeau
# 40880      18.14.06                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#           channel_title              publish_time  \
# 40876   Annoying Orange  2018-06-13T18:00:07.000Z
# 40877  Elhiwar Ettounsi  2018-06-13T19:01:18.000Z
# 40878    Kingdom Hearts  2018-06-11T17:30:53.000Z
# 40879   The Young Turks  2018-06-13T04:00:05.000Z
# 40880          我愛小明星大跟班  2018-06-13T16:00:03.000Z
#
#                                                     tags   views  likes  \
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...   80685   1701
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...  103339    460
# ...

# %%
df['trending_day'] = df['trending_date'].apply(lambda x: x[3: 5])

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df['trending_month'] = df['trending_date'].apply(lambda x: x[6: 8])

# %%
df['trending_month']
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 40876    06
# 40877    06
# 40878    06
# 40879    06
# 40880    06
# Name: trending_month, Length: 39585, dtype: object

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
sns.countplot(df['trending_month'], )
# Out:
# <AxesSubplot:xlabel='trending_month', ylabel='count'>

# %%
sns.countplot(df['trending_year'])
# Out:
# <AxesSubplot:xlabel='trending_year', ylabel='count'>

# %%
df['title_length'] = df['title'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
plt.figure(figsize = (15, 5))
sns.scatterplot(x = 'views', y = 'title_length', data = df)
# Out:
# <AxesSubplot:xlabel='views', ylabel='title_length'>

# %%
plt.figure(figsize = (15, 5))
sns.scatterplot(x = 'likes', y = 'title_length', data = df)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='title_length'>

# %%
plt.figure(figsize = (10, 10))
sns.scatterplot(x = 'likes', y = 'views', hue = 'comments_disabled', data = df)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='views'>

# %%
import datetime

# %%
datetime.datetime.strptime
# Out:
# <function datetime.strptime>

# %%
df.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title              publish_time  \
# 0    EminemVEVO  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso  2017-11-12T19:05:24.000Z
# 3      nigahiga  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# ...

# %%
df['publish_year'] = df['publish_time'].apply(lambda x: datetime.datetime.strptime(x[: 10], '%Y-%m-%d').year)
df['publish_month'] = df['publish_time'].apply(lambda x: datetime.datetime.strptime(x[: 10], '%Y-%m-%d').month)
df['publish_day'] = df['publish_time'].apply(lambda x: datetime.datetime.strptime(x[: 10], '%Y-%m-%d').day)

# %%
df.drop(['trending_date', 'publish_time'], axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 5))
plt.xticks(rotation = 45)
sns.countplot(df[df['comments_disabled'] == 1]['category'])
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %%
plt.figure(figsize = (15, 5))
plt.xticks(rotation = 45)
sns.countplot(df[df['ratings_disabled'] == 1]['category'])
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %%
df.head()
# Out:
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# ...

# %%
df['publish_month'].unique()
# Out:
# array([11, 10,  2, 12,  9,  3,  5,  4,  1,  8,  7,  6], dtype=int64)

# %%
month_mapping = {1: 'January', 2: 'February', 3: 'March',4: 'April',5: 'May',6: 'June',7: 'July',8:'August',
                 9: 'September', 10: 'October',
                 11: 'November', 12: 'December'}

# %%
month_mapping
# Out:
# {1: 'January',
#  2: 'February',
#  3: 'March',
#  4: 'April',
#  5: 'May',
#  6: 'June',
#  7: 'July',
#  8: 'August',
#  9: 'September',
#  10: 'October',
#  11: 'November',
#  12: 'December'}

# %%
plt.figure(figsize = (15, 5))

sns.countplot(df['publish_month'].map(month_mapping))
# Out:
# <AxesSubplot:xlabel='publish_month', ylabel='count'>

# %%
df.head()
# Out:
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# ...

# %%
df['description_length'] = df['description'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# ...

# %%
sns.scatterplot(x = 'views', y = 'description_length', data = df)
# Out:
# <AxesSubplot:xlabel='views', ylabel='description_length'>

# %%
corr_df = df[['views', 'likes', 'dislikes', 'comment_count', 
              'trending_year', 'trending_day', 'trending_month', 'title_length', 'publish_year', 
              'publish_month', 'publish_day', 'description_length']].corr()

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(corr_df, annot = True, cmap = "viridis")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = 'comment_count', y = 'likes', data = df)
# Out:
# <AxesSubplot:xlabel='comment_count', ylabel='likes'>

# %%
plt.figure(figsize = (10, 10))
sns.regplot(x = 'comment_count', y = 'likes', data = df)
# Out:
# <AxesSubplot:xlabel='comment_count', ylabel='likes'>

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = 'likes', y = 'dislikes', data = df)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='dislikes'>

# %%
plt.figure(figsize = (10, 10))
sns.regplot(x = 'likes', y = 'dislikes', data = df)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='dislikes'>

# %%
plt.figure(figsize = (10, 10))
sns.regplot(x = 'likes', y = 'views', data = df)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='views'>
